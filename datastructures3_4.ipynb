# %%
#Lab3:Circular linked lists

class Node:
  def __init__(self,data):
    self.data=data
    self.next=None
def push(head,data):
  newP=Node(data)
  newP.next=head

  if head!=None:
    temp=head
    while(temp.next!=head):
      temp=temp.next
    temp.next=newP
  else:
    newP.next=newP
  head=newP
  return head

def printLL(head):
  if head==None:
    print("Linked List is Empty")
    return
  temp=head.next
  print(head.data,end=" ")
  if (head!=None):
    while temp!=head:
      print(temp.data,end=" ")
      temp=temp.next
  print()

def deleteNode(head,key):
  if head==None:
    return
  if head.data==key and head.next==head:
    head=None
    return
  last=head
  if head.data==key:
    while last.next==head.next:
      last=last.next
    last.next=head.next
    head=last.next
    return
  while last.next!=head and last.next.data!=key:
    last=last.next
  if last.next.data==key:
    d=last.next
    last.next=d.next
    d=None
  else:
    print("Given node is not found in the list")

head=None

head=push(head, 2)
head=push(head, 5)
head=push(head, 7)
head=push(head,8)
head=push(head,10)

print("List before deletion:")
printLL(head)
deleteNode(head,7)
print("List after deletion:")
printLL(head)
# Out:
# List before deletion:
# 10 8 7 5 2
# List after deletion:
# 10 8 5 2

# %%
#Lab4: Stack Implementation Using Singly Linked List
class Node:
  def __init__(self,x):
    self.data=x
    self.next=None
class Stack:
  def __init__(self):
    self.top=None
  def push(self):
    x=int(input("Enter element to be inserted in stack: "))
    new=Node(x)
    if self.top is None:
      self.top=new
      self.top.next=None
    else:
      new.next=self.top
      self.top=new
  def pop(self):
    if self.top is None:
      print("Stack is empty")
    elif self.top.next is None:
      print("Popped element is: ", self.top.data)
      print("_______")
      self.top=None
    else:
      temp=self.top
      print("Popped element is: ", self.top.data)
      print("_______")
      self.top=temp.next
      temp=None
  def display(self):
    if self.top is None:
      print("Stack is empty")
      print("_______")
    else:
      print("Elements of the stack are: ")
      temp=self.top
      while temp:
        print(temp.data)
        temp=temp.next
      print("Top of stack is:", self.top.data)
s=Stack()
while(1):
  print("Enter the option from below:")
  print("1:Push\n2:Pop\n3:Display\n4:Quit")
  opt=int(input())
  if opt==1:
    print("Push")
    s.push()
  elif opt==2:
    print("Pop")
    s.pop()
  elif opt==3:
    print("Display")
    s.display()
  else:
    break
# Out:
# Enter the option from below:
# 1:Push
# 2:Pop
# 3:Display
# 4:Quit
# 1
# Push
# Enter element to be inserted in stack: 10
# Enter the option from below:
# 1:Push
# 2:Pop
# 3:Display
# 4:Quit
# 1
# Push
# Enter element to be inserted in stack: 20
# Enter the option from below:
# 1:Push
# 2:Pop
# 3:Display
# 4:Quit
# 1
# Push
# Enter element to be inserted in stack: 30
# Enter the option from below:
# 1:Push
# 2:Pop
# 3:Display
# 4:Quit
# 3
# Display
# Elements of the stack are:
# 30
# Top of stack is: 30
# 20
# Top of stack is: 30
# 10
# Top of stack is: 30
# Enter the option from below:
# 1:Push
# 2:Pop
# 3:Display
# 4:Quit
# 4
